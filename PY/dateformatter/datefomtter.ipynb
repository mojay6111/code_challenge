# %% [markdown]
# # ✅ **Python Solution**

# %%
def format_date(date_str):
    if not isinstance(date_str, str):
        raise ValueError('Input must be a string in the format "Month day, year".')

    s = date_str.strip()

    import re
    pattern = r'^([A-Za-z]+)\s+(\d{1,2}),\s*(\d{4})$'
    match = re.match(pattern, s)
    if not match:
        raise ValueError('Invalid format. Expected "Month day, year" (e.g., "December 6, 2025").')

    month_name, day_str, year_str = match.groups()
    month_name = month_name.lower()

    months = {
        'january': 1, 'february': 2, 'march': 3, 'April': 4,
        'may': 5, 'june': 6, 'july': 7, 'august': 8,
        'september': 9, 'october': 10, 'november': 11, 'december': 12
    }
    months = {k.lower(): v for k, v in months.items()}  # normalize

    if month_name not in months:
        raise ValueError(f'Invalid month name: "{month_name}".')

    month = months[month_name]
    day = int(day_str)
    year = int(year_str)

    import calendar
    days_in_month = calendar.monthrange(year, month)[1]

    if not (1 <= day <= days_in_month):
        raise ValueError(f"{month_name.capitalize()} {day}, {year} is not a valid date.")

    return f"{year:04d}-{month:02d}-{day:02d}"

# %%
# Example usage:
date_str = "December 6, 2025"
formatted_date = format_date(date_str)
print(formatted_date)
# Out:
# 2025-12-06

# %% [markdown]
# # 🔍 **DETAILED EXPLANATION OF EVERY PART**
#
# ---
#
# ## **1. Function definition**
#
# ```python
# def format_date(date_str):
# ```
#
# * Creates a function that takes one argument: the input date string.
#
# ---
#
# ## **2. Ensure input is a string**
#
# ```python
#     if not isinstance(date_str, str):
#         raise ValueError('Input must be a string in the format "Month day, year".')
# ```
#
# Why:
#
# * Prevents errors if someone passes an integer, list, None, etc.
# * Stops bad data early.
#
# ---
#
# ## **3. Remove extra whitespace**
#
# ```python
#     s = date_str.strip()
# ```
#
# Why:
#
# * `" December 6, 2025 "` becomes `"December 6, 2025"`
# * Prevents regex from failing due to spaces.
#
# ---
#
# ## **4. Use regex to extract Month, Day, Year**
#
# ```python
#     import re
#     pattern = r'^([A-Za-z]+)\s+(\d{1,2}),\s*(\d{4})$'
#     match = re.match(pattern, s)
# ```
#
# Pattern explanation:
#
# | Part          | Meaning            |
# | ------------- | ------------------ |
# | `^`           | Start of string    |
# | `([A-Za-z]+)` | Month name         |
# | `\s+`         | One or more spaces |
# | `(\d{1,2})`   | Day (1–2 digits)   |
# | `,`           | Literal comma      |
# | `\s*`         | Optional spaces    |
# | `(\d{4})`     | Year (4 digits)    |
# | `$`           | End of string      |
#
# Example `"December 6, 2025"` matches perfectly.
#
# ---
#
# ## **5. Handle invalid formats**
#
# ```python
#     if not match:
#         raise ValueError('Invalid format. Expected "Month day, year"...')
# ```
#
# Bad examples:
#
# * `"Dec 6 2025"`
# * `"December 6 2025"`
# * `"December, 6 2025"`
# * `"Random text"`
#
# ---
#
# ## **6. Extract matched values**
#
# ```python
#     month_name, day_str, year_str = match.groups()
# ```
#
# Example values:
#
# * `"December"`
# * `"6"`
# * `"2025"`
#
# ---
#
# ## **7. Normalize month name**
#
# ```python
#     month_name = month_name.lower()
# ```
#
# So `"December"` → `"december"`
#
# ---
#
# ## **8. Month lookup table**
#
# ```python
#     months = {
#         'january': 1, 'february': 2, 'march': 3, 'April': 4,
#         'may': 5, 'june': 6, 'july': 7, 'august': 8,
#         'september': 9, 'october': 10, 'november': 11, 'december': 12
#     }
# ```
#
# We convert month names to numbers.
#
# Then make all keys lowercase:
#
# ```python
#     months = {k.lower(): v for k, v in months.items()}
# ```
#
# ---
#
# ## **9. Validate month name**
#
# ```python
#     if month_name not in months:
#         raise ValueError(f'Invalid month name: "{month_name}".')
# ```
#
# Example invalid:
#
# * `"Decembrr"`
# * `"Januarie"`
#
# ---
#
# ## **10. Convert day and year to integers**
#
# ```python
#     month = months[month_name]
#     day = int(day_str)
#     year = int(year_str)
# ```
#
# Example:
#
# * `"6"` → `6`
# * `"2025"` → `2025`
#
# ---
#
# ## **11. Get number of days in the given month/year**
#
# ```python
#     import calendar
#     days_in_month = calendar.monthrange(year, month)[1]
# ```
#
# `calendar.monthrange(year, month)` returns:
#
# * Index of weekday (0–6)
# * Number of days in the month
#
# Example:
#
# * February 2024 → `29`
# * February 2023 → `28`
#
# ---
#
# ## **12. Validate realistic date**
#
# ```python
#     if not (1 <= day <= days_in_month):
#         raise ValueError(f"{month_name.capitalize()} {day}, {year} is not a valid date.")
# ```
#
# Invalid examples:
#
# * `"February 30, 2024"`
# * `"April 31, 2023"`
#
# ---
#
# ## **13. Format final output**
#
# ```python
#     return f"{year:04d}-{month:02d}-{day:02d}"
# ```
#
# Formatting rules:
#
# * `{year:04d}` → ensures 4 digits
# * `{month:02d}` → zero-pads (`1` → `"01"`)
# * `{day:02d}` → zero-pads (`6` → `"06"`)
#
# Output:
#
# ```
# 2025-12-06
# ```
#
# ---
#
# # 🎯 Final Thoughts: How to Think Through These Problems
#
# When you face a transformation problem like this:
#
# ### **1. Understand input format deeply**
#
# * What can vary?
# * What must remain consistent?
# * Are there extra spaces? Irregular capitalization?
#
# ### **2. Extract the important pieces**
#
# * Regex
# * String splitting
# * Parsing numbers
# * Lookup tables
#
# ### **3. Validate everything**
#
# * Types
# * Month correctness
# * Day range
# * Leap years
#
# ### **4. Format the output cleanly**
#
# * Padding
# * Output string construction
#
# ### **5. Keep the logic modular and readable**
#
# * Don’t mix parsing, validation, and formatting in one messy block.
